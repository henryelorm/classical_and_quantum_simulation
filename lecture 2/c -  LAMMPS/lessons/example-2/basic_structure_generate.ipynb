# %%
from ase.io.lammpsdata import write_lammps_data

# %%
from ase.build import graphene_nanoribbon
from ase.io import write

graphene = graphene_nanoribbon(12, 9, type='zigzag', vacuum=10)


graphene.center()

write('graphene.data', graphene, format='lammps-data', masses=True)
